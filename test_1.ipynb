# %% [markdown]
# <a href="https://colab.research.google.com/github/angie-10/codingground/blob/test_branch/test_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10;
b=20;
c=10+20;
print(c);
# Out:
# 30
